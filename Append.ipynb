# %%
import warnings
import pandas as pd
warnings.filterwarnings('ignore')

dat_pass = pd.read_csv('data_password_5.csv',sep=',')
dat_map = pd.read_csv('data_map_5.csv',sep=',')

# %%
dat_all_0 = dat_pass.append(dat_map)
#dat_all_1 = dat_all_0.append(dat_shop)
#dat_all_2 = dat_all_1.append(dat_video)
#dat_all = dat_all_2.reset_index(drop=True)
#dat_all
dat_all_0 = dat_all_0.reset_index(drop=True)
dat_all_0
# Out:
#       Unnamed: 0        X_Max        Y_Max      Dist_Max        X_Min  \
# 0              0   962.726772  1174.025238  39062.500000    31.933112
# 1              1   962.726772  1387.759873  39062.500000    31.933112
# 2              2   962.726772  1387.759873  39062.500000     3.483106
# 3              3   962.726772  1387.759873  39062.500000     3.483106
# 4              4   962.726772  1387.759873  39062.500000     3.483106
# ...          ...          ...          ...           ...          ...
# 6579        5263  2047.717571  1993.963299  13671.875000  1290.420967
# 6580        5264  2047.717571  1993.963299  13671.875000   142.126532
# 6581        5265  2047.717571  1993.963299  13671.875000   142.126532
# 6582        5266  2047.717571  1232.562030  13671.875000   142.126532
# 6583        5267  2047.717571  1232.562030   8324.661811   142.126532
#
#            Y_Min      Dist_Min       X_Mean      Y_Mean    Dist_Mean  \
# ...

# %%
#dat_all['Subject'] = 'M'
#dat_all
dat_all_0['subject'] = '5'
dat_all_0
# Out:
#       Unnamed: 0        X_Max        Y_Max      Dist_Max        X_Min  \
# 0              0   962.726772  1174.025238  39062.500000    31.933112
# 1              1   962.726772  1387.759873  39062.500000    31.933112
# 2              2   962.726772  1387.759873  39062.500000     3.483106
# 3              3   962.726772  1387.759873  39062.500000     3.483106
# 4              4   962.726772  1387.759873  39062.500000     3.483106
# ...          ...          ...          ...           ...          ...
# 6579        5263  2047.717571  1993.963299  13671.875000  1290.420967
# 6580        5264  2047.717571  1993.963299  13671.875000   142.126532
# 6581        5265  2047.717571  1993.963299  13671.875000   142.126532
# 6582        5266  2047.717571  1232.562030  13671.875000   142.126532
# 6583        5267  2047.717571  1232.562030   8324.661811   142.126532
#
#            Y_Min      Dist_Min       X_Mean      Y_Mean    Dist_Mean  \
# ...

# %%
dat_all_0.to_csv('data_5.csv')
